# %%
##----------------------------------------
# Check mesh!
import logging
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import capytaine as cpt
import meshio
from scipy.linalg import block_diag


mesh=meshio.read('Compund44.msh')

mesh
# Out:
# <meshio mesh object>
#   Number of points: 3927
#   Number of cells:
#     vertex: 1
#     vertex: 1
#     vertex: 1
#     vertex: 1
#     vertex: 1
#     vertex: 1
#     vertex: 1
#     vertex: 1
#     line: 14
#     line: 10
#     line: 26
#     line: 64
#     line: 26
#     line: 40
#     line: 10
#     line: 14
#     line: 64
#     line: 26
#     line: 40
#     line: 10
#     line: 14
#     triangle: 2072
#     triangle: 1136
#     triangle: 2032
#     triangle: 1128
#   Cell sets: gmsh:bounding_entities
#   Point data: gmsh:dim_tags
#   Cell data: gmsh:geometrical

# %%
import logging
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import capytaine as cpt
import meshio
from scipy.linalg import block_diag

# Set up logging
logging.basicConfig(level=logging.INFO,
                    format="%(levelname)s:\t%(message)s")

# Load in diamond mesh via gmsh -

mesh=meshio.read('Diamond333.msh')
#mesh=meshio.read('Diamond7Sept.msh')
body = cpt.FloatingBody.from_meshio(mesh, name = "Diamond")
body.keep_immersed_part()

# Solve with direct Solver:

body .translate_z(-5e-3)

body.add_all_rigid_body_dofs()
#body.add_translation_dof(name="Heave")

body.center_of_mass = (0, 0, -4)

# Add hydrostatic data

m = 1040838

Ixx = 3.859E7
Ixy = -20
Ixz = 10
Iyy = 9.842E+06
Iyz = 5.553
Izz = 9.842E+06

I = np.array([[Ixx,Ixy,Ixz],
              [Ixy,Iyy,Iyz],
              [Ixz,Iyz,Izz]])

M = block_diag(m,m,m,I)
#M = block_diag(m)
body.mass = body.add_dofs_labels_to_matrix(M)


K33 = 1.1656E+06
K34 = -3.2159E+00
K35 = -2.7730E+00
K44 = 2.6603E+07
K45 = 0.0000E+00
K55 = 2.6603E+07

StiffnessMatrix = np.array([[K33,K34,K35],[K34,K44,K45],[K35,K45,K55]])
kHS = block_diag(0,0,StiffnessMatrix,0)
#kHS = block_diag(K33)

body.hydrostatic_stiffness = body.add_dofs_labels_to_matrix(kHS)

test_matrix = xr.Dataset(coords={
    'omega': np.linspace(0.20, 1.05,171),
    'radiating_dof': list(body.dofs.keys()),
    'wave_direction': [0],
    'rho': 1000})

Di = cpt.BEMSolver(green_function=cpt.XieDelhommeau()).fill_dataset(test_matrix, [body],
                                                                   hydrostatics=True,
                                                                    mesh=True,
                                                                    wavelength=True,
                                                                    wavenumber=True)
# Out:
# INFO:	Stored 6368 triangle faces as quadrilaterals
# INFO:	New floating body: Diamond.
# INFO:	Clipping Diamond with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:	Clipping Diamond_mesh by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# WARNING:	The rotation dof Roll has been initialized around the origin of the domain (0, 0, 0).
# WARNING:	The rotation dof Pitch has been initialized around the origin of the domain (0, 0, 0).
# WARNING:	The rotation dof Yaw has been initialized around the origin of the domain (0, 0, 0).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.200, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.200, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.200, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.200, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.200, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.200, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.200, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.205, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.205, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.205, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.205, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.205, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.205, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.205, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.210, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.210, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.210, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.210, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.210, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.210, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.210, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.215, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.215, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.215, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.215, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.215, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.215, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.215, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.220, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.220, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.220, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.220, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.220, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.220, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.220, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.225, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.225, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.225, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.225, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.225, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.225, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.225, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.230, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.230, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.230, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.230, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.230, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.230, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.230, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.235, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.235, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.235, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.235, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.235, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.235, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.235, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.240, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.240, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.240, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.240, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.240, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.240, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.240, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.245, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.245, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.245, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.245, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.245, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.245, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.245, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.250, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.250, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.250, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.250, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.250, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.250, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.250, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.255, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.255, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.255, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.255, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.255, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.255, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.255, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.260, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.260, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.260, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.260, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.260, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.260, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.260, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.265, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.265, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.265, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.265, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.265, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.265, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.265, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.270, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.270, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.270, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.270, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.270, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.270, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.270, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.275, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.275, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.275, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.275, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.275, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.275, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.275, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.280, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.280, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.280, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.280, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.280, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.280, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.280, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.285, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.285, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.285, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.285, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.285, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.285, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.285, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.290, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.290, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.290, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.290, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.290, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.290, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.290, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.295, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.295, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.295, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.295, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.295, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.295, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.295, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.300, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.300, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.300, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.300, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.300, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.300, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.300, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.305, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.305, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.305, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.305, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.305, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.305, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.305, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.310, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.310, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.310, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.310, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.310, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.310, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.310, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.315, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.315, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.315, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.315, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.315, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.315, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.315, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.320, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.320, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.320, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.320, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.320, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.320, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.320, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.325, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.325, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.325, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.325, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.325, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.325, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.325, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.330, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.330, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.330, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.330, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.330, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.330, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.330, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.335, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.335, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.335, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.335, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.335, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.335, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.335, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.340, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.340, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.340, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.340, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.340, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.340, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.340, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.345, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.345, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.345, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.345, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.345, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.345, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.345, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.350, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.350, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.350, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.350, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.350, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.350, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.350, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.355, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.355, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.355, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.355, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.355, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.355, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.355, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.360, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.360, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.360, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.360, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.360, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.360, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.360, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.365, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.365, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.365, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.365, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.365, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.365, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.365, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.370, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.370, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.370, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.370, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.370, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.370, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.370, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.375, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.375, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.375, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.375, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.375, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.375, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.375, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.380, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.380, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.380, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.380, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.380, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.380, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.380, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.385, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.385, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.385, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.385, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.385, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.385, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.385, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.390, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.390, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.390, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.390, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.390, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.390, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.390, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.395, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.395, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.395, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.395, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.395, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.395, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.395, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.400, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.400, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.400, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.400, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.400, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.400, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.400, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.405, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.405, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.405, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.405, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.405, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.405, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.405, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.410, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.410, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.410, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.410, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.410, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.410, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.410, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.415, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.415, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.415, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.415, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.415, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.415, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.415, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.420, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.420, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.420, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.420, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.420, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.420, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.420, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.425, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.425, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.425, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.425, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.425, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.425, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.425, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.430, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.430, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.430, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.430, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.430, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.430, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.430, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.435, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.435, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.435, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.435, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.435, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.435, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.435, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.440, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.440, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.440, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.440, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.440, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.440, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.440, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.445, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.445, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.445, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.445, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.445, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.445, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.445, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.450, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.450, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.450, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.450, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.450, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.450, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.450, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.455, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.455, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.455, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.455, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.455, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.455, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.455, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.460, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.460, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.460, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.460, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.460, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.460, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.460, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.465, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.465, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.465, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.465, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.465, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.465, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.465, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.470, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.470, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.470, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.470, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.470, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.470, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.470, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.475, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.475, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.475, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.475, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.475, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.475, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.475, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.480, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.480, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.480, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.480, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.480, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.480, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.480, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.485, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.485, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.485, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.485, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.485, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.485, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.485, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.490, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.490, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.490, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.490, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.490, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.490, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.490, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.495, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.495, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.495, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.495, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.495, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.495, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.495, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.500, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.500, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.500, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.500, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.500, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.500, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.500, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.505, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.505, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.505, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.505, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.505, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.505, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.505, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.510, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.510, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.510, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.510, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.510, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.510, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.510, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.515, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.515, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.515, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.515, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.515, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.515, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.515, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.520, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.520, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.520, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.520, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.520, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.520, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.520, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.525, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.525, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.525, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.525, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.525, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.525, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.525, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.530, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.530, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.530, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.530, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.530, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.530, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.530, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.535, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.535, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.535, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.535, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.535, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.535, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.535, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.540, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.540, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.540, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.540, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.540, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.540, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.540, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.545, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.545, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.545, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.545, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.545, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.545, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.545, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.550, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.550, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.550, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.550, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.550, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.550, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.550, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.555, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.555, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.555, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.555, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.555, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.555, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.555, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.560, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.560, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.560, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.560, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.560, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.560, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.560, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.565, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.565, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.565, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.565, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.565, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.565, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.565, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.570, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.570, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.570, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.570, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.570, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.570, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.570, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.575, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.575, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.575, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.575, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.575, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.575, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.575, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.580, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.580, depth=inf, radiating_dof=Surge).
# ...
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.925, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.925, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.925, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.925, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.925, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.930, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.930, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.930, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.930, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.930, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.930, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.930, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.935, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.935, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.935, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.935, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.935, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.935, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.935, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.940, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.940, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.940, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.940, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.940, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.940, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.940, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.945, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.945, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.945, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.945, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.945, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.945, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.945, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.950, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.950, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.950, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.950, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.950, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.950, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.950, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.955, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.955, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.955, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.955, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.955, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.955, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.955, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.960, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.960, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.960, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.960, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.960, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.960, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.960, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.965, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.965, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.965, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.965, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.965, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.965, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.965, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.970, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.970, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.970, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.970, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.970, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.970, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.970, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.975, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.975, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.975, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.975, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.975, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.975, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.975, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.980, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.980, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.980, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.980, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.980, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.980, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.980, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.985, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.985, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.985, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.985, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.985, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.985, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.985, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.990, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.990, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.990, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.990, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.990, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.990, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.990, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=0.995, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.995, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.995, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.995, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.995, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.995, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=0.995, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.000, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.000, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.000, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.000, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.000, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.000, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.000, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.005, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.005, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.005, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.005, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.005, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.005, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.005, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.010, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.010, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.010, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.010, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.010, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.010, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.010, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.015, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.015, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.015, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.015, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.015, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.015, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.015, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.020, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.020, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.020, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.020, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.020, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.020, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.020, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.025, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.025, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.025, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.025, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.025, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.025, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.025, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.030, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.030, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.030, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.030, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.030, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.030, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.030, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.035, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.035, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.035, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.035, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.035, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.035, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.035, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.040, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.040, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.040, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.040, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.040, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.040, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.040, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.045, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.045, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.045, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.045, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.045, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.045, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.045, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Diamond, omega=1.050, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.050, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.050, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.050, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.050, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.050, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Diamond, omega=1.050, depth=inf, radiating_dof=Yaw).

# %%
import matplotlib.pyplot as plt

dofs = ["Heave","Surge","Sway"]
#dofs = ["Heave"]

# Constant for Non-Dom
DiR = 6.15
DiC = (1000*DiR*DiR*DiR)

# Added Mass vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Di['omega'],
        Di['added_mass'].sel(radiating_dof=dof, influenced_dof=dof),
        label=dof)
plt.xlabel('omega')
plt.ylabel('added mass')
plt.legend()
plt.tight_layout()


# Radiation damping vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Di['omega'],
        Di['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof),
        label=dof)  
plt.xlabel('omega')
plt.ylabel('Radiation Damping')
plt.legend()
plt.tight_layout()


# Compute RAO
#d = 7200000
d = 0
#dampingMatrix = np.transpose(np.repeat(d,140))
dampingMatrix = d
Di['RAO'] = cpt.post_pro.rao(Di,dissipation=dampingMatrix)

# RAO vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Di['omega'],
        np.abs(Di['RAO'].sel(radiating_dof=dof)),
        label=dof)
plt.xlabel('omega')
plt.ylabel('RAO')
plt.legend()
plt.tight_layout()
plt.show()




# Added mass vs. kR
plt.figure()
for dof in dofs:
    plt.plot(
        Di['wavenumber']*DiR,
        Di['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/DiC,
        label=dof)
plt.xlabel('kR')
plt.ylabel('added mass/(rho*R^3)')
plt.legend()
plt.tight_layout()

# radiation damping vs. kR
plt.figure()
for dof in dofs:
    plt.plot(
        Di['wavenumber']*DiR,
        Di['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/(Di['omega']*DiC),
        label=dof)
plt.xlabel('kR')
plt.ylabel('Radiation Damping/(omega.rho.R^3)')
plt.legend()
plt.tight_layout()

# RAO vs. kR
plt.figure()
for dof in dofs:
    plt.plot(
        Di['wavenumber']*DiR,
        np.abs(Di['RAO'].sel(radiating_dof=dof)),
        label=dof)
plt.xlabel('kR')
plt.ylabel('RAO')
plt.legend()
plt.tight_layout()
plt.show()

plt.show()
# Out:
# INFO:	Compute RAO.

# %%
##----------------------------------------------------------------

# %%
import logging
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import capytaine as cpt
import meshio
from scipy.linalg import block_diag

# Set up logging
logging.basicConfig(level=logging.INFO,
                    format="%(levelname)s:\t%(message)s")


# Load in diamond mesh via gmsh -

mesh=meshio.read('compund11Sept.msh')
body = cpt.FloatingBody.from_meshio(mesh, name = "compund")

# Setup Body
body .translate_z(-5e-2)
body.center_of_mass = (0, 0, -6)
body.add_all_rigid_body_dofs()

# Add inertial from meshmagick
m = 1728000
Ixx = 1.461E+08
Ixy = -20
Ixz = 10
Iyy = 1.542E+08
Iyz = 5.553
Izz = 7.601E+07
I = np.array([[Ixx,Ixy,Ixz],
              [Ixy,Iyy,Iyz],
              [Ixz,Iyz,Izz]])

M = block_diag(m,m,m,I)
body.mass = body.add_dofs_labels_to_matrix(M)

# Add hydrodynamic data from meshmagick
K33 = 1.8510E+06
K34 = 1.7776E+05
K35 = 1.3532E+06
K44 = 2.3468E+07
K45 = 1.0829E+05
K55 = 2.4441E+07

StiffnessMatrix = np.array([[K33,K34,K35],[K34,K44,K45],[K35,K45,K55]])
kHS = block_diag(0,0,StiffnessMatrix,0)


body.hydrostatic_stiffness = body.add_dofs_labels_to_matrix(kHS)

# Setup Problem
test_matrix = xr.Dataset(coords={
    'omega': np.linspace(0.35,1.05,10),
    'radiating_dof': list(body.dofs.keys()),
    'wave_direction': [0],
    'rho': 1000
})
# Solve Problem
Cm = cpt.BEMSolver(green_function=cpt.XieDelhommeau()).fill_dataset(test_matrix, [body],
                                                                   hydrostatics=True,
                                                                    mesh=True,
                                                                    wavelength=True,
                                                                    wavenumber=True)
# Out:
# INFO:	Stored 4720 triangle faces as quadrilaterals
# INFO:	New floating body: compund.
# INFO:	The rotation dof Roll has been initialized around the point: compund.center_of_mass = (0, 0, -6)
# INFO:	The rotation dof Pitch has been initialized around the point: compund.center_of_mass = (0, 0, -6)
# INFO:	The rotation dof Yaw has been initialized around the point: compund.center_of_mass = (0, 0, -6)
# INFO:	Solve DiffractionProblem(body=compund, omega=0.350, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=compund, omega=0.350, depth=inf, radiating_dof=Surge).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6b67db8ac9e1> in <module>
#      73                                                                     mesh=True,
#      74                                                                     wavelength=True,
# ---> 75                                                                     wavenumber=True)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/capytaine/bem/solver.py in fill_dataset(self, dataset, bodies, **kwargs)
#     148             dataset.update(kochin)
#     149         else:
# --> 150             results = self.solve_all(problems, keep_details=False)
#     151             dataset = assemble_dataset(results, attrs=attrs, **kwargs)
#     152         return dataset
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/capytaine/bem/solver.py in solve_all(self, problems, **kwargs)
#     123             the solved problems
#     124         """
# --> 125         return [self.solve(problem, **kwargs) for problem in sorted(problems)]
#     126
#     127     def fill_dataset(self, dataset, bodies, **kwargs):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/capytaine/bem/solver.py in <listcomp>(.0)
#     123             the solved problems
#     124         """
# --> 125         return [self.solve(problem, **kwargs) for problem in sorted(problems)]
#     126
#     127     def fill_dataset(self, dataset, bodies, **kwargs):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/capytaine/bem/solver.py in solve(self, problem, keep_details)
#      87             self.green_function
#      88         )
# ---> 89         sources = self.engine.linear_solver(K, problem.boundary_condition)
#      90         potential = S @ sources
#      91
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/capytaine/matrices/linear_solvers.py in solve_gmres(A, b)
#      92
#      93     else:
# ---> 94         x, info = ssl.gmres(A, b, atol=1e-6)
#      95
#      96     if info != 0:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/sparse/linalg/isolve/iterative.py in gmres(A, b, x0, tol, restart, maxiter, M, callback, restrt, atol, callback_type)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/_lib/_threadsafety.py in caller(func, *a, **kw)
#      42         def caller(func, *a, **kw):
#      43             with self:
# ---> 44                 return func(*a, **kw)
#      45         return scipy._lib.decorator.decorate(func, caller)
#      46
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/sparse/linalg/isolve/iterative.py in gmres(A, b, x0, tol, restart, maxiter, M, callback, restrt, atol, callback_type)
#     621         elif (ijob == 3):
#     622             work[slice2] *= sclr2
# --> 623             work[slice2] += sclr1*matvec(work[slice1])
#     624             if resid_ready:
#     625                 if callback_type in ('pr_norm', 'legacy'):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/sparse/linalg/interface.py in matvec(self, x)
#     230             raise ValueError('dimension mismatch')
#     231
# --> 232         y = self._matvec(x)
#     233
#     234         if isinstance(x, np.matrix):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/sparse/linalg/interface.py in _matvec(self, x)
#     197         will define matrix-vector multiplication as well.
#     198         """
# --> 199         return self.matmat(x.reshape(-1, 1))
#     200
#     201     def matvec(self, x):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/sparse/linalg/interface.py in matmat(self, X)
#     335                              % (self.shape, X.shape))
#     336
# --> 337         Y = self._matmat(X)
#     338
#     339         if isinstance(Y, np.matrix):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/sparse/linalg/interface.py in _matmat(self, X)
#     729
#     730     def _matmat(self, X):
# --> 731         return self.A.dot(X)
#     732
#     733     def _adjoint(self):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

#dofs = ["Heave","Surge","Sway"]
dofs = ["Heave"]

# Constant for Non-Dom
CmR = 7.75
CmC = (1000*CmR*CmR*CmR)
CmR
 


# Added Mass vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Cm['omega'],
        Cm['added_mass'].sel(radiating_dof=dof, influenced_dof=dof),
        label=dof)
plt.xlabel('omega')
plt.ylabel('added mass')
plt.legend()
plt.tight_layout()


# Radiation damping vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Cm['omega'],
        Cm['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof),
        label=dof)  
plt.xlabel('omega')
plt.ylabel('Radiation Damping')
plt.legend()
plt.tight_layout()




# Compute RAO
d = 0
d= 720000
#dampingMatrix = np.transpose(np.repeat(d,13))
dampingMatrix = d
Cm['RAO'] = cpt.post_pro.rao(Cm,dissipation = d)

# RAO vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Cm['omega'],
        np.abs(Cm['RAO'].sel(radiating_dof=dof)),
        label =dof)
plt.xlabel('omega')
plt.ylabel('RAO')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure()
for dof in dofs:
    plt.plot(
        Cm['omega'],
        np.abs(Cm['excitation_force'].sel(influenced_dof=dof)),
        label=dof)  
plt.xlabel('omega')
plt.ylabel('Excitation Force (N)')
plt.legend()
plt.tight_layout()


# Added mass vs. kR
plt.figure()
for dof in dofs:
    plt.plot(
        Cm['wavenumber']*CmR,
        Cm['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/CmC,
        label=dof)
plt.xlabel('kR')
plt.ylabel('added mass/(rho*R^3)')
plt.legend()
plt.tight_layout()

# radiation damping vs. kR
plt.figure()
for dof in dofs:
    plt.plot(
        Cm['wavenumber']*CmR,
        Cm['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/(Cm['omega']*CmC),
        label=dof)
plt.xlabel('kR')
plt.ylabel('Radiation Damping/(omega.rho.R^3)')
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# INFO:	Compute RAO.

# %%
dof = ['Heave']
min(Cm['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c96fff3972df> in <module>
#       1 dof = ['Heave']
# ----> 2 min(Cm['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof))
#
# NameError: name 'Cm' is not defined

# %%
# Compute RAO
d = 0
d= 720000
dampingMatrix = np.transpose(np.repeat(d,119))
Cm['RAO'] = cpt.post_pro.rao(Cm,dissipation=dampingMatrix)
d = [0,100000,200000,400000,600000,800000,1000000,1200000,1500000]
# RAO vs. omega
plt.figure()
for dof in dofs:
    for damps in d:
        dampingMatrix = damps
        Cm['RAO'] = cpt.post_pro.rao(Cm,dissipation=dampingMatrix)
        plt.plot(
            Cm['omega'],
            np.abs(Cm['RAO'].sel(radiating_dof=dof)),
            label=damps)
plt.xlabel('omega')
plt.ylabel('RAO')
plt.legend()
plt.tight_layout()
plt.show()
WavePower = 0.25*1000*9.81*(Cm['omega']/Cm['wavenumber'])/1000
# Power graph
plt.figure()
for dof in dofs:
    for damps in d:
        dampingMatrix = damps
        Cm['RAO'] = cpt.post_pro.rao(Cm,dissipation=dampingMatrix)
        power = (1/np.pi)*np.abs(Cm['RAO'].sel(radiating_dof=dof))*Cm['omega']*damps/1000
        plt.plot(
            Cm['omega'],
            power,
            label=damps)
        
plt.plot(Cm['omega'],WavePower)
plt.xlabel('omega')
plt.ylabel('Power [kW] ')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure()
plt.plot(Cm['omega'],WavePower)
# Out:
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.
# INFO:	Compute RAO.

# %%
# Cylinder

import logging
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import capytaine as cpt
import meshio
from scipy.linalg import block_diag

# Set up logging
logging.basicConfig(level=logging.INFO,
                    format="%(levelname)s:\t%(message)s")



# Load in diamond mesh via gmsh -

mesh=meshio.read('Cylinder45.msh')
body = cpt.FloatingBody.from_meshio(mesh, name = "Cylinder")
body.keep_immersed_part()

# Solve with direct Solver:

body .translate_z(-5e-2)

body.add_all_rigid_body_dofs()
#body.add_translation_dof(name="Heave")

# Add hydrostatic data

m = 10.844938E6
Ixx = 1.336E9
Ixy = -19.40
Ixz = 113.5
Iyy = 1.336E9
Iyz = 5.553
Izz = 1.101E9

I = np.array([[Ixx,Ixy,Ixz],
              [Ixy,Iyy,Iyz],
              [Ixz,Iyz,Izz]])

M = block_diag(m,m,m,I)
#M = [[m]]
body.mass = body.add_dofs_labels_to_matrix(M)

K33 = 6.2582E+06
K34 = 1.6148E+01
K35 = 1.6882E+00
K44 = -1.6105E+07
K45 = -1.3335E+01
K55 = -1.6105E+08

StiffnessMatrix = np.array([[K33,K34,K35],[K34,K44,K45],[K35,K45,K55]])
kHS = block_diag(0,0,StiffnessMatrix,0)
#kHS = [[K33]]


body.hydrostatic_stiffness = body.add_dofs_labels_to_matrix(kHS)

test_matrix = xr.Dataset(coords={
    'omega': np.linspace(0.355, 1.05,140),
    'radiating_dof': list(body.dofs.keys()),
    'wave_direction': [0],
    'rho': 1000
})

Cy = cpt.BEMSolver(green_function=cpt.XieDelhommeau()).fill_dataset(test_matrix, [body],
                                                                   hydrostatics=True,
                                                                    mesh=True,
                                                                    wavelength=True,
                                                                    wavenumber=True)
# Out:
# INFO:	Stored 6688 triangle faces as quadrilaterals
# INFO:	New floating body: Cylinder.
# INFO:	Clipping Cylinder with respect to Plane(normal=[0. 0. 1.], point=[0. 0. 0.])
# INFO:	Clipping Cylinder_mesh by Plane(normal=[0. 0. 1.], point=[0. 0. 0.]): no action.
# WARNING:	The rotation dof Roll has been initialized around the origin of the domain (0, 0, 0).
# WARNING:	The rotation dof Pitch has been initialized around the origin of the domain (0, 0, 0).
# WARNING:	The rotation dof Yaw has been initialized around the origin of the domain (0, 0, 0).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.355, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.355, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.355, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.355, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.355, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.355, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.355, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.360, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.360, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.360, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.360, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.360, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.360, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.360, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.365, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.365, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.365, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.365, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.365, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.365, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.365, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.370, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.370, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.370, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.370, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.370, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.370, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.370, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.375, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.375, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.375, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.375, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.375, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.375, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.375, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.380, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.380, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.380, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.380, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.380, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.380, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.380, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.385, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.385, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.385, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.385, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.385, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.385, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.385, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.390, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.390, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.390, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.390, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.390, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.390, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.390, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.395, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.395, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.395, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.395, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.395, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.395, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.395, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.400, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.400, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.400, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.400, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.400, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.400, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.400, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.405, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.405, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.405, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.405, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.405, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.405, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.405, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.410, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.410, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.410, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.410, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.410, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.410, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.410, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.415, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.415, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.415, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.415, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.415, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.415, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.415, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.420, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.420, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.420, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.420, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.420, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.420, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.420, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.425, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.425, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.425, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.425, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.425, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.425, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.425, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.430, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.430, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.430, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.430, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.430, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.430, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.430, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.435, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.435, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.435, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.435, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.435, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.435, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.435, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.440, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.440, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.440, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.440, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.440, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.440, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.440, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.445, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.445, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.445, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.445, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.445, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.445, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.445, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.450, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.450, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.450, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.450, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.450, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.450, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.450, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.455, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.455, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.455, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.455, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.455, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.455, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.455, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.460, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.460, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.460, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.460, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.460, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.460, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.460, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.465, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.465, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.465, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.465, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.465, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.465, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.465, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.470, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.470, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.470, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.470, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.470, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.470, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.470, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.475, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.475, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.475, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.475, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.475, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.475, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.475, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.480, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.480, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.480, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.480, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.480, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.480, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.480, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.485, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.485, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.485, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.485, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.485, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.485, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.485, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.490, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.490, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.490, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.490, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.490, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.490, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.490, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.495, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.495, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.495, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.495, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.495, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.495, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.495, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.500, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.500, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.500, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.500, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.500, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.500, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.500, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.505, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.505, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.505, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.505, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.505, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.505, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.505, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.510, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.510, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.510, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.510, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.510, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.510, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.510, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.515, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.515, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.515, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.515, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.515, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.515, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.515, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.520, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.520, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.520, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.520, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.520, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.520, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.520, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.525, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.525, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.525, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.525, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.525, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.525, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.525, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.530, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.530, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.530, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.530, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.530, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.530, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.530, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.535, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.535, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.535, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.535, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.535, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.535, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.535, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.540, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.540, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.540, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.540, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.540, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.540, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.540, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.545, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.545, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.545, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.545, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.545, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.545, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.545, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.550, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.550, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.550, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.550, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.550, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.550, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.550, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.555, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.555, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.555, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.555, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.555, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.555, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.555, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.560, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.560, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.560, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.560, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.560, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.560, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.560, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.565, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.565, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.565, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.565, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.565, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.565, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.565, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.570, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.570, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.570, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.570, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.570, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.570, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.570, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.575, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.575, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.575, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.575, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.575, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.575, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.575, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.580, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.580, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.580, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.580, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.580, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.580, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.580, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.585, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.585, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.585, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.585, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.585, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.585, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.585, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.590, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.590, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.590, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.590, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.590, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.590, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.590, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.595, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.595, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.595, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.595, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.595, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.595, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.595, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.600, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.600, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.600, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.600, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.600, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.600, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.600, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.605, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.605, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.605, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.605, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.605, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.605, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.605, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.610, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.610, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.610, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.610, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.610, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.610, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.610, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.615, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.615, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.615, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.615, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.615, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.615, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.615, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.620, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.620, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.620, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.620, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.620, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.620, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.620, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.625, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.625, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.625, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.625, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.625, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.625, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.625, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.630, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.630, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.630, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.630, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.630, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.630, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.630, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.635, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.635, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.635, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.635, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.635, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.635, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.635, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.640, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.640, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.640, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.640, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.640, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.640, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.640, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.645, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.645, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.645, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.645, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.645, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.645, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.645, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.650, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.650, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.650, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.650, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.650, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.650, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.650, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.655, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.655, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.655, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.655, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.655, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.655, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.655, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.660, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.660, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.660, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.660, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.660, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.660, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.660, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.665, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.665, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.665, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.665, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.665, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.665, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.665, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.670, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.670, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.670, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.670, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.670, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.670, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.670, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.675, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.675, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.675, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.675, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.675, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.675, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.675, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.680, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.680, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.680, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.680, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.680, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.680, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.680, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.685, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.685, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.685, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.685, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.685, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.685, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.685, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.690, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.690, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.690, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.690, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.690, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.690, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.690, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.695, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.695, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.695, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.695, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.695, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.695, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.695, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.700, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.700, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.700, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.700, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.700, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.700, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.700, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.705, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.705, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.705, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.705, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.705, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.705, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.705, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.710, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.710, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.710, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.710, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.710, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.710, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.710, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.715, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.715, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.715, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.715, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.715, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.715, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.715, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.720, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.720, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.720, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.720, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.720, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.720, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.720, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.725, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.725, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.725, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.725, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.725, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.725, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.725, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.730, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.730, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.730, depth=inf, radiating_dof=Sway).
# ...
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.925, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.925, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.925, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.930, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.930, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.930, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.930, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.930, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.930, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.930, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.935, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.935, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.935, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.935, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.935, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.935, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.935, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.940, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.940, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.940, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.940, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.940, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.940, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.940, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.945, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.945, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.945, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.945, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.945, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.945, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.945, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.950, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.950, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.950, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.950, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.950, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.950, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.950, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.955, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.955, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.955, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.955, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.955, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.955, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.955, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.960, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.960, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.960, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.960, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.960, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.960, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.960, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.965, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.965, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.965, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.965, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.965, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.965, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.965, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.970, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.970, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.970, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.970, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.970, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.970, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.970, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.975, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.975, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.975, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.975, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.975, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.975, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.975, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.980, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.980, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.980, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.980, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.980, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.980, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.980, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.985, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.985, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.985, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.985, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.985, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.985, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.985, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.990, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.990, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.990, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.990, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.990, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.990, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.990, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=0.995, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.995, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.995, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.995, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.995, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.995, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=0.995, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.000, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.000, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.000, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.000, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.000, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.000, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.000, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.005, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.005, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.005, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.005, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.005, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.005, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.005, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.010, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.010, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.010, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.010, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.010, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.010, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.010, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.015, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.015, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.015, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.015, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.015, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.015, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.015, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.020, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.020, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.020, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.020, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.020, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.020, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.020, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.025, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.025, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.025, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.025, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.025, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.025, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.025, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.030, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.030, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.030, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.030, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.030, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.030, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.030, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.035, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.035, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.035, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.035, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.035, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.035, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.035, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.040, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.040, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.040, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.040, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.040, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.040, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.040, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.045, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.045, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.045, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.045, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.045, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.045, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.045, depth=inf, radiating_dof=Yaw).
# INFO:	Solve DiffractionProblem(body=Cylinder, omega=1.050, depth=inf, wave_direction=0.000).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.050, depth=inf, radiating_dof=Surge).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.050, depth=inf, radiating_dof=Sway).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.050, depth=inf, radiating_dof=Heave).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.050, depth=inf, radiating_dof=Roll).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.050, depth=inf, radiating_dof=Pitch).
# INFO:	Solve RadiationProblem(body=Cylinder, omega=1.050, depth=inf, radiating_dof=Yaw).

# %%
import matplotlib.pyplot as plt

dofs = ["Heave","Surge","Sway"]
#dofs = ["Heave"]

# Constant for Non-Dom
CyR = 14.25
CyC = (1000*CyR*CyR*CyR)


# Added Mass vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Cy['omega'],
        Cy['added_mass'].sel(radiating_dof=dof, influenced_dof=dof),
        label=dof)
plt.xlabel('omega')
plt.ylabel('added mass')
plt.legend()
plt.tight_layout()


# Radiation damping vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Cy['omega'],
        Cy['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof),
        label=dof)  
plt.xlabel('omega')
plt.ylabel('Radiation Damping')
plt.legend()
plt.tight_layout()


# Compute RAO
Cy['RAO'] = cpt.post_pro.rao(Cy)

# RAO vs. omega
plt.figure()
for dof in dofs:
    plt.plot(
        Cy['omega'],
        np.abs(Cy['RAO'].sel(radiating_dof=dof)),
        label=dof)
plt.xlabel('omega')
plt.ylabel('RAO')
plt.legend()
plt.tight_layout()
plt.show()




# Added mass vs. kR
plt.figure()
for dof in dofs:
    plt.plot(
        Cy['wavenumber']*CyR,
        Cy['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/CyC,
        label=dof)
plt.xlabel('kR')
plt.ylabel('added mass/(rho*R^3)')
plt.legend()
plt.tight_layout()

# radiation damping vs. kR
plt.figure()
for dof in dofs:
    plt.plot(
        Cy['wavenumber']*CyR,
        Cy['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/(Cy['omega']*CyC),
        label=dof)
plt.xlabel('kR')
plt.ylabel('Radiation Damping/(omega.rho.R^3)')
plt.legend()
plt.tight_layout()

# RAO vs. kR
plt.figure()
for dof in dofs:
    plt.plot(
        Cy['wavenumber']*CyR,
        np.abs(Cy['RAO'].sel(radiating_dof=dof)),
        label=dof)
plt.xlabel('kR')
plt.ylabel('RAO')
plt.legend()
plt.tight_layout()
plt.show()

plt.show()
# Out:
# INFO:	Compute RAO.

# %%
# All Together Now!

# Added mass vs. kR
import matplotlib.pyplot as plt

CyR = 14.25
CmR = 7.75
DiR = 6.25

CyC = 1000*CyR*CyR*CyR
CmC = 1000*CmR*CmR*CmR
DiC = 1000*DiR*DiR*DiR

dofs = ["Heave"]

plt.figure()
for dof in dofs:
    plt.plot(Cy['wavenumber']*CyR,Cy['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/CyC,
        label='Cylinder')
    plt.plot(Cm['wavenumber']*CmR,Cm['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/CmC,
            label='Compound')
    plt.plot(Di['wavenumber']*DiR,Di['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/DiC,
        label='Diamond')
    
plt.xlabel('kR')
plt.ylabel('added mass/(rho*R^3)')
plt.legend()
plt.tight_layout()


plt.figure()    
for dof in ["Heave"]:
    plt.plot(Cy['wavenumber']*CyR,Cy['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/CyC,
        label='Cylinder')
    plt.plot(Cm['wavenumber']*CmR,Cm['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/CmC,
            label='Compound')
    plt.plot(Di['wavenumber']*DiR,Di['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/DiC,
        label='Diamond')
plt.xlabel('kR')
plt.ylabel('Radiation Damping/(omega.rho.R^3)')
plt.legend()
plt.tight_layout()


# RAO vs. kR
plt.figure()
for dof in dofs:
    plt.plot(Cy['wavenumber']*CyR,np.abs(Cy['RAO'].sel(radiating_dof=dof)),label='Cylinder')
    plt.plot(Cm['wavenumber']*CmR,np.abs(Cm['RAO'].sel(radiating_dof=dof)),label='Compound')
    plt.plot(Di['wavenumber']*DiR,np.abs(Di['RAO'].sel(radiating_dof=dof)),label='Diamond')

plt.xlabel('kR')
plt.ylabel('RAO')
plt.legend()
plt.tight_layout()
plt.show()

plt.show()

# %%
# Out:
# <xarray.DataArray 'excitation_force' (omega: 119, wave_direction: 1, influenced_dof: 6)>
# array([[[2.06744798e+06, 1.94147019e+02, 4.32604655e+06, 8.95354604e+02,
#          1.25990091e+07, 8.25467891e+02]],
#
#        [[2.12220498e+06, 1.99302658e+02, 4.28161615e+06, 9.14678184e+02,
#          1.29328120e+07, 8.46173287e+02]],
#
#        [[2.17751461e+06, 2.04588785e+02, 4.23704996e+06, 9.33805401e+02,
#          1.32699874e+07, 8.67025925e+02]],
#
#        [[2.23336542e+06, 2.09843048e+02, 4.19235535e+06, 9.52547372e+02,
#          1.36104782e+07, 8.88004741e+02]],
#
#        [[2.28975999e+06, 2.15210019e+02, 4.14753962e+06, 9.71255495e+02,
#          1.39540749e+07, 9.09109862e+02]],
#
#        [[2.34669294e+06, 2.20599260e+02, 4.10261219e+06, 9.90067106e+02,
#          1.43007535e+07, 9.30358755e+02]],
#
#        [[2.40414781e+06, 2.26101381e+02, 4.05758398e+06, 1.00881699e+03,
#          1.46504815e+07, 9.51717886e+02]],
# ...
#        [[5.18550999e+06, 2.30391653e+02, 6.25686507e+05, 2.16619475e+03,
#          2.92682772e+07, 2.58573425e+03]],
#
#        [[5.14424804e+06, 2.22764082e+02, 6.11045270e+05, 2.18828361e+03,
#          2.89854277e+07, 2.61166894e+03]],
#
#        [[5.10262737e+06, 2.15027213e+02, 5.96689110e+05, 2.23024616e+03,
#          2.87008152e+07, 2.63768820e+03]],
#
#        [[5.06069078e+06, 2.06962496e+02, 5.82619745e+05, 2.21273341e+03,
#          2.84147617e+07, 2.66408120e+03]],
#
#        [[5.01847041e+06, 2.00573614e+02, 5.68846298e+05, 2.23177645e+03,
#          2.81274232e+07, 2.69051466e+03]],
#
#        [[4.97600878e+06, 1.93729686e+02, 5.55347131e+05, 2.26985620e+03,
#          2.78390806e+07, 2.71800270e+03]],
#
#        [[4.93332760e+06, 1.84867899e+02, 5.42124427e+05, 2.24813047e+03,
#          2.75498307e+07, 2.74548385e+03]]])
# Coordinates:
#     g                  float64 9.81
#     rho                int64 1000
#     body_name          <U8 'Cylinder'
#     water_depth        float64 inf
#   * omega              (omega) float64 0.355 0.36 0.365 ... 0.935 0.94 0.945
#   * influenced_dof     (influenced_dof) object 'Surge' 'Sway' ... 'Pitch' 'Yaw'
#   * wave_direction     (wave_direction) float64 0.0
#     wavenumber         (omega) float64 0.01285 0.01321 ... 0.09007 0.09103
#     wavelength         (omega) float64 489.1 475.6 462.7 ... 70.51 69.76 69.02
#     nb_faces           int64 5104
#     quadrature_method  <U4 'None'

# %%
# Added mass vs. kR
plt.figure()

CyR = 14.25
CmR = 7.75
DiR = 6.25

CyC = 1000*CyR*CyR*CyR
CmC = 1000*CmR*CmR*CmR
DiC = 1000*DiR*DiR*DiR


for dof in ["Heave"]:
    plt.plot(Cy['wavenumber']*14.5,Cy['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/CyC,
        label='Cylinder')
    plt.plot(Cm['wavenumber']*10,Cm['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/CmC,
            label='Compound')
    plt.plot(Di['wavenumber']*6.25,Di['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/DiC,
        label='Diamond')
    
plt.xlabel('kR')
plt.ylabel('added mass/(rho*R^3)')
plt.legend()
plt.tight_layout()

# radiation damping vs. kR
plt.figure()    
for dof in ["Heave"]:
    plt.plot(Cy['wavenumber']*CyR,Cy['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/CyC,
        label='Cylinder')
    plt.plot(Cm['wavenumber']*CmR,Cm['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/CmC,
            label='Compound')
    plt.plot(Di['wavenumber']*DiR,Di['radiation_damping'].sel(radiating_dof=dof, influenced_dof=dof)/DiC,
        label='Diamond')
plt.xlabel('kR')
plt.ylabel('Radiation Damping/(omega.rho.R^3)')
plt.legend()
plt.tight_layout()

# RAO vs. omega
plt.figure()
for dof in ["Heave"]:
    plt.plot(Cy['omega'],np.abs(Cy['RAO'].sel(radiating_dof=dof)),label='Cylinder')
    plt.plot(Cm['omega'],np.abs(Cm['RAO'].sel(radiating_dof=dof)),label='Compound')
    plt.plot(Di['omega'],np.abs(Di['RAO'].sel(radiating_dof=dof)),label='Diamond')

plt.xlabel('omega')
plt.ylabel('RAO')
plt.legend()
plt.tight_layout()


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5a0690394e1d> in <module>
#      12
#      13 for dof in ["Heave"]:
# ---> 14     plt.plot(Cy['wavenumber']*14.5,Cy['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/CyC,
#      15         label='Cylinder')
#      16     plt.plot(Cm['wavenumber']*10,Cm['added_mass'].sel(radiating_dof=dof, influenced_dof=dof)/CmC,
#
# NameError: name 'Cy' is not defined

# %%
# Save Results

from capytaine.io.xarray import separate_complex_values
#separate_complex_values(Cm).to_netcdf("CompoundResults6Sept.nc")
#separate_complex_values(Cy).to_netcdf("CylinderResults31Aug.nc")
separate_complex_values(Di).to_netcdf("DiamondResults14Sept.nc")
